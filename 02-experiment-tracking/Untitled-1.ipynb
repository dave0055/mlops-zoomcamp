# %%
from mlflow.tracking import MlflowClient

MLFLOW_TRACKING_URI = "sqlite:///mlflow.db"

client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)
# Out:
# 2026/07/01 13:12:01 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/07/01 13:12:01 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.

# %%
client.create_experiment(name="my-cool-experiment")
# Out:
# '2'

# %%
from mlflow.entities import ViewType

runs = client.search_runs(
    experiment_ids=["1"],
    filter_string="",
    run_view_type=ViewType.ACTIVE_ONLY,
    max_results=5,
    order_by=["metrics.rmse ASC"]
)

# %%
for run in runs:
    print(f"run id: {run.info.run_id}, rmse: {run.data.metrics['rmse']:.4f}")
# Out:
# run id: c7052dbe3c314e80b560115463cb71e4, rmse: 6.3154
# run id: fca04a4cce63468a822fd1248790d2f9, rmse: 6.3162
# run id: f1a9ea6301e54e68a1b81cd7d19f9c79, rmse: 6.3162
# run id: b175a9bc26fd4b31bc84510bf17104c0, rmse: 6.3819
# run id: a679f3a919344175b906478376c7a936, rmse: 6.6353

# %%
import mlflow

mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# %%
run_id = "f1a9ea6301e54e68a1b81cd7d19f9c79"
model_uri = f"runs:/{run_id}/model"
mlflow.register_model(model_uri=model_uri, name="nyc-taxi-regressor")
